# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Подготовка данных</a></span><ul class="toc-item"><li><span><a href="#Обзор-данных" data-toc-modified-id="Обзор-данных-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Обзор данных</a></span></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Обработка-дубликатов" data-toc-modified-id="Обработка-дубликатов-1.2.1"><span class="toc-item-num">1.2.1&nbsp;&nbsp;</span>Обработка дубликатов</a></span></li><li><span><a href="#Обработка-пропусков" data-toc-modified-id="Обработка-пропусков-1.2.2"><span class="toc-item-num">1.2.2&nbsp;&nbsp;</span>Обработка пропусков</a></span></li></ul></li><li><span><a href="#Обработка-и-кодирование-категориальных-признаков" data-toc-modified-id="Обработка-и-кодирование-категориальных-признаков-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Обработка и кодирование категориальных признаков</a></span><ul class="toc-item"><li><span><a href="#Разделение-данных-на-обучающую,-валидационную-и-тестовую-выборки." data-toc-modified-id="Разделение-данных-на-обучающую,-валидационную-и-тестовую-выборки.-1.3.1"><span class="toc-item-num">1.3.1&nbsp;&nbsp;</span>Разделение данных на обучающую, валидационную и тестовую выборки.</a></span></li></ul></li></ul></li><li><span><a href="#Исследование-задачи" data-toc-modified-id="Исследование-задачи-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Исследование задачи</a></span><ul class="toc-item"><li><span><a href="#Обучение-модели-на-датасете-с-параметром-Tenure" data-toc-modified-id="Обучение-модели-на-датасете-с-параметром-Tenure-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Обучение модели на датасете с параметром Tenure</a></span></li><li><span><a href="#Обучение-модели-на-датасете-без-параметра-Tenure" data-toc-modified-id="Обучение-модели-на-датасете-без-параметра-Tenure-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Обучение модели на датасете без параметра Tenure</a></span></li><li><span><a href="#Подбор-гиперпараметров" data-toc-modified-id="Подбор-гиперпараметров-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Подбор гиперпараметров</a></span><ul class="toc-item"><li><span><a href="#Модель-для-первого-датасета" data-toc-modified-id="Модель-для-первого-датасета-2.3.1"><span class="toc-item-num">2.3.1&nbsp;&nbsp;</span>Модель для первого датасета</a></span></li><li><span><a href="#Модель-для-второго-датасета" data-toc-modified-id="Модель-для-второго-датасета-2.3.2"><span class="toc-item-num">2.3.2&nbsp;&nbsp;</span>Модель для второго датасета</a></span></li><li><span><a href="#Обучение-моделей-после-подбора-гиперпараметров" data-toc-modified-id="Обучение-моделей-после-подбора-гиперпараметров-2.3.3"><span class="toc-item-num">2.3.3&nbsp;&nbsp;</span>Обучение моделей после подбора гиперпараметров</a></span></li><li><span><a href="#Промежуточные-выводы" data-toc-modified-id="Промежуточные-выводы-2.3.4"><span class="toc-item-num">2.3.4&nbsp;&nbsp;</span>Промежуточные выводы</a></span></li></ul></li></ul></li><li><span><a href="#Борьба-с-дисбалансом" data-toc-modified-id="Борьба-с-дисбалансом-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Борьба с дисбалансом</a></span><ul class="toc-item"><li><span><a href="#Дерево-решений" data-toc-modified-id="Дерево-решений-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Дерево решений</a></span><ul class="toc-item"><li><span><a href="#На-основе-датасета-с-параметром-Tenure" data-toc-modified-id="На-основе-датасета-с-параметром-Tenure-3.1.1"><span class="toc-item-num">3.1.1&nbsp;&nbsp;</span>На основе датасета с параметром Tenure</a></span></li><li><span><a href="#На-основе-датасета-без-параметра-Tenure" data-toc-modified-id="На-основе-датасета-без-параметра-Tenure-3.1.2"><span class="toc-item-num">3.1.2&nbsp;&nbsp;</span>На основе датасета без параметра Tenure</a></span></li></ul></li><li><span><a href="#Случайный-лес" data-toc-modified-id="Случайный-лес-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Случайный лес</a></span><ul class="toc-item"><li><span><a href="#На-основе-датасета-с-параметром-Tenure" data-toc-modified-id="На-основе-датасета-с-параметром-Tenure-3.2.1"><span class="toc-item-num">3.2.1&nbsp;&nbsp;</span>На основе датасета с параметром Tenure</a></span></li><li><span><a href="#На-основе-датасета-без-параметра-Tenure" data-toc-modified-id="На-основе-датасета-без-параметра-Tenure-3.2.2"><span class="toc-item-num">3.2.2&nbsp;&nbsp;</span>На основе датасета без параметра Tenure</a></span></li></ul></li><li><span><a href="#Логистическая-регрессия" data-toc-modified-id="Логистическая-регрессия-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Логистическая регрессия</a></span><ul class="toc-item"><li><span><a href="#На-основе-датасета-с-параметром-Tenure" data-toc-modified-id="На-основе-датасета-с-параметром-Tenure-3.3.1"><span class="toc-item-num">3.3.1&nbsp;&nbsp;</span>На основе датасета с параметром Tenure</a></span></li><li><span><a href="#На-основе-датасета-без-параметра-Tenure" data-toc-modified-id="На-основе-датасета-без-параметра-Tenure-3.3.2"><span class="toc-item-num">3.3.2&nbsp;&nbsp;</span>На основе датасета без параметра Tenure</a></span></li></ul></li><li><span><a href="#Промежуточные-выводы" data-toc-modified-id="Промежуточные-выводы-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Промежуточные выводы</a></span></li><li><span><a href="#Подбор-гиперпараметров-для-лучших-моделей" data-toc-modified-id="Подбор-гиперпараметров-для-лучших-моделей-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Подбор гиперпараметров для лучших моделей</a></span><ul class="toc-item"><li><span><a href="#Модель-для-первого-датасета" data-toc-modified-id="Модель-для-первого-датасета-3.5.1"><span class="toc-item-num">3.5.1&nbsp;&nbsp;</span>Модель для первого датасета</a></span></li><li><span><a href="#Модель-для-второго-датасета" data-toc-modified-id="Модель-для-второго-датасета-3.5.2"><span class="toc-item-num">3.5.2&nbsp;&nbsp;</span>Модель для второго датасета</a></span></li><li><span><a href="#Анализ-полученных-гиперпараметров" data-toc-modified-id="Анализ-полученных-гиперпараметров-3.5.3"><span class="toc-item-num">3.5.3&nbsp;&nbsp;</span>Анализ полученных гиперпараметров</a></span></li><li><span><a href="#Последнее-сравнение-моделей" data-toc-modified-id="Последнее-сравнение-моделей-3.5.4"><span class="toc-item-num">3.5.4&nbsp;&nbsp;</span>Последнее сравнение моделей</a></span><ul class="toc-item"><li><span><a href="#На-основе-датасета-с-параметром-Tenure-и-настройкой-class_weight" data-toc-modified-id="На-основе-датасета-с-параметром-Tenure-и-настройкой-class_weight-3.5.4.1"><span class="toc-item-num">3.5.4.1&nbsp;&nbsp;</span>На основе датасета с параметром Tenure и настройкой class_weight</a></span></li><li><span><a href="#На-основе-датасета-c-параметром-Tenure-и-техникой-upsample" data-toc-modified-id="На-основе-датасета-c-параметром-Tenure-и-техникой-upsample-3.5.4.2"><span class="toc-item-num">3.5.4.2&nbsp;&nbsp;</span>На основе датасета c параметром Tenure и техникой upsample</a></span></li><li><span><a href="#Выбор-лучшей-модели" data-toc-modified-id="Выбор-лучшей-модели-3.5.4.3"><span class="toc-item-num">3.5.4.3&nbsp;&nbsp;</span>Выбор лучшей модели</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#Тестирование-модели" data-toc-modified-id="Тестирование-модели-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Тестирование модели</a></span></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Выводы</a></span></li></ul></div>

# %% [markdown]
# # Отток клиентов

# %% [markdown]
# Проект для компании "Бета-Банк". Вследствие оттока клиентов маркетологи банка подсчитали, что сохранять текущих клиентов дешевле, чем привлекать новых. Требуется построить систему, способную проанализировать поведение клиентов банка и спрогнозировать, уйдет клиент из банка в ближайшее время или нет. В нашем распоряжении исторические данные о поведении клиентов и расторжении договоров с банком. Нужно построить модель c предельно большим значением F1-меры.
#
# Цель проекта: изучить полученные данные, изучить задачу, обучить, изучить и сравнить различные модели, и выбрать модель с максимальным значением F1-меры(оно должно быть не менее 0.59). Дополнительно следует измерять ROC-AUC, сравнивая ее с F1-мерой.
#
# Ход выполнения проекта: данные получены из [открытого источника](https://www.kaggle.com/datasets/barelydedicated/bank-customer-churn-modeling). О качестве данных ничего известно, поэтому возможно потребуется предобработка прежде чем можно будет приступить к построению моделей. Изучим баланс классов, попробуем его исправить, рассмотрим как ведут себя различные модели в условиях дисбаланса классов и без него,  переберем разные наборы гиперпараметров и выберем лучшую модель. Таким образом, проект будет выполнен в 8 этапов:
#
# 1. Обзор данных
# 2. Предобработка данных
# 3. Изучение баланса классов
# 4. Проверка моделей на несбалансированных данных
# 5. Борьба с дисбалансом классов
# 6. Проверка моделей на сбалансированных данных
# 7. Выбор лучшей модели
# 8. Проверка лучшей модели на тестовой выборке

# %% [markdown]
# ## Подготовка данных

# %% [markdown]
# ### Обзор данных

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import f1_score
from sklearn.metrics import roc_curve, roc_auc_score
from sklearn.model_selection import validation_curve
from sklearn.utils import shuffle

# %%
data = pd.read_csv('datasets/Churn.csv')
data.shape
# Out:
# (10000, 14)

# %%
data.head(5)
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0     2.0       0.00              1          1               1
# 1     1.0   83807.86              1          0               1
# 2     8.0  159660.80              3          1               0
# 3     1.0       0.00              2          0               0
# 4     2.0  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           9091 non-null   float64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(3), int64(8), object(3)
# memory usage: 1.1+ MB

# %%
data.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age       Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  9091.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800     4.997690
# std     2886.89568  7.193619e+04     96.653299     10.487806     2.894723
# min        1.00000  1.556570e+07    350.000000     18.000000     0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000     2.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000     5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000     7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000    10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# ...

# %% [markdown]
# В даных 14 столбцов, хранящих различные данные, согласно полученной документации:
#
# **Признаки**
# * `RowNumber` — индекс строки в данных
# * `CustomerId` — уникальный идентификатор клиента
# * `Surname` — фамилия
# * `CreditScore` — кредитный рейтинг
# * `Geography` — страна проживания
# * `Gender` — пол
# * `Age` — возраст
# * `Tenure` — сколько лет человек является клиентом банка
# * `Balance` — баланс на счёте
# * `NumOfProducts` — количество продуктов банка, используемых клиентом
# * `HasCrCard` — наличие кредитной карты
# * `IsActiveMember` — активность клиента
# * `EstimatedSalary` — предполагаемая зарплата
#
# **Целевой признак**
#
# * `Exited` — факт ухода клиента

# %% [markdown]
# Индекс строки в данных нам не понадобится, поэтому сразу его удалим

# %%
data = data.drop('RowNumber', axis=1)

# %%
numeric = ['CreditScore', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'EstimatedSalary'] 
categ = ['CustomerId', 'HasCrCard', 'IsActiveMember', 'Surname', 'Geography', 'Gender']

# %%
sns.pairplot(data.drop(['CustomerId', 'Surname'], axis=1), hue='Exited');

# %%
fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(data.corr(), annot=True, fmt='.1f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Сильные корреляции в данных отсутсвуют

# %% [markdown]
# ### Предобработка данных

# %% [markdown]
# #### Обработка дубликатов

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Дубликаты в данных отсутствуют

# %% [markdown]
# #### Обработка пропусков

# %%
data.isna().sum()
# Out:
# CustomerId           0
# Surname              0
# CreditScore          0
# Geography            0
# Gender               0
# Age                  0
# Tenure             909
# Balance              0
# NumOfProducts        0
# HasCrCard            0
# IsActiveMember       0
# EstimatedSalary      0
# Exited               0
# dtype: int64

# %% [markdown]
# В столбце `Tenure` обнаружены пропуски, причем их достаточно много, 9% от всего датасета.

# %% [markdown]
# Посмотрим на распределение данных в этом столбце

# %%
data['Tenure'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# Можно попробовать заполнить пропущенные значения, чтобы сохранить данные из других столбцов, однако это может достаточно сильно исказить последующий прогноз, поэтому попробуем 2 варианта:
#
# - удалить весь этот признак и обучить модель без него, затем оценить результат. Судя по тепловой карте этот признак не имеет сильной корреляции с целевым, поэтому можно спокойно попробовать убрать его из датасета и посмотреть на итог.
# - удалить пропущенные значения и обучить модель на оставшихся данных, затем также оценить результат.

# %% [markdown]
# ### Обработка и кодирование категориальных признаков

# %% [markdown]
# Избавимся от столбцов CustomerId и Surname, так как эти признаки вряд ли принесут пользу при обучении моделей

# %%
data = data.drop(['CustomerId', 'Surname'], axis=1)

# %% [markdown]
# Закодируем оставшиеся категориальные признаки с помощью техники One-Hot Encoding

# %%
data_ohe = pd.get_dummies(data, columns=['Gender', 'Geography'], drop_first=1)

# %%
data_ohe
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619   42     2.0       0.00              1          1
# 1             608   41     1.0   83807.86              1          0
# 2             502   42     8.0  159660.80              3          1
# 3             699   39     1.0       0.00              2          0
# 4             850   43     2.0  125510.82              1          1
# ...           ...  ...     ...        ...            ...        ...
# 9995          771   39     5.0       0.00              2          1
# 9996          516   35    10.0   57369.61              1          1
# 9997          709   36     7.0       0.00              1          0
# 9998          772   42     3.0   75075.31              2          1
# 9999          792   28     NaN  130142.79              1          1
#
#       IsActiveMember  EstimatedSalary  Exited  Gender_Male  Geography_Germany  \
# ...

# %% [markdown]
# Кодирование категориальных колонок произведено успешно. Теперь на основе полученного датасета создадим новый, без признака `Tenure`.

# %%
data_ohe_wout_tenure = data_ohe.drop('Tenure', axis=1)

# %%
data_ohe_wout_tenure
# Out:
#       CreditScore  Age    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0             619   42       0.00              1          1               1
# 1             608   41   83807.86              1          0               1
# 2             502   42  159660.80              3          1               0
# 3             699   39       0.00              2          0               0
# 4             850   43  125510.82              1          1               1
# ...           ...  ...        ...            ...        ...             ...
# 9995          771   39       0.00              2          1               0
# 9996          516   35   57369.61              1          1               1
# 9997          709   36       0.00              1          0               1
# 9998          772   42   75075.31              2          1               0
# 9999          792   28  130142.79              1          1               0
#
# ...

# %% [markdown]
# Удалим из датасета **data_ohe** пропущенные значения в колонке `Tenure`

# %%
data_ohe = data_ohe.dropna(subset=['Tenure']).reset_index(drop=True)

# %%
data_ohe
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619   42     2.0       0.00              1          1
# 1             608   41     1.0   83807.86              1          0
# 2             502   42     8.0  159660.80              3          1
# 3             699   39     1.0       0.00              2          0
# 4             850   43     2.0  125510.82              1          1
# ...           ...  ...     ...        ...            ...        ...
# 9086          800   29     2.0       0.00              2          0
# 9087          771   39     5.0       0.00              2          1
# 9088          516   35    10.0   57369.61              1          1
# 9089          709   36     7.0       0.00              1          0
# 9090          772   42     3.0   75075.31              2          1
#
#       IsActiveMember  EstimatedSalary  Exited  Gender_Male  Geography_Germany  \
# ...

# %% [markdown]
# Итоговые датасеты получены, приступим к разделению их на выборки

# %% [markdown]
# #### Разделение данных на обучающую, валидационную и тестовую выборки.

# %% [markdown]
# Выделим параметры и целевой признак из датасета с праметром `Tenure`

# %%
features_first = data_ohe.drop('Exited', axis=1)
target_first = data_ohe['Exited']

# %% [markdown]
# Выделим параметры и целевой признак из датасета без праметра `Tenure`

# %%
features_scnd = data_ohe_wout_tenure.drop('Exited', axis=1)
target_scnd = data_ohe_wout_tenure['Exited']

# %% [markdown]
# Разделим выборки на обучающую и тестовую

# %%
features_first_train, features_first_test, target_first_train, target_first_test = train_test_split(features_first,
                                                                                                    target_first,
                                                                                                   random_state=1,
                                                                                                   test_size=0.2)

# %%
features_scnd_train, features_scnd_test, target_scnd_train, target_scnd_test = train_test_split(features_scnd,
                                                                                                    target_scnd,
                                                                                                   random_state=1,
                                                                                                   test_size=0.2)

# %% [markdown]
# Из обучающих выборок выделим валидационную выборку

# %%
features_first_train, features_first_valid, target_first_train, target_first_valid = train_test_split(features_first_train,
                                                                                                    target_first_train,
                                                                                                   random_state=1,
                                                                                                   test_size=0.25)

# %%
features_scnd_train, features_scnd_valid, target_scnd_train, target_scnd_valid = train_test_split(features_scnd_train,
                                                                                                    target_scnd_train,
                                                                                                   random_state=1,
                                                                                                   test_size=0.25)

# %% [markdown]
# Посмотрим на размеры полученных выборок

# %%
print(features_first_train.shape, features_first_valid.shape, features_first_test.shape)
# Out:
# (5454, 11) (1818, 11) (1819, 11)

# %%
print(target_first_train.shape, target_first_valid.shape, target_first_test.shape)
# Out:
# (5454,) (1818,) (1819,)

# %%
print(features_scnd_train.shape, features_scnd_valid.shape, features_scnd_test.shape)
# Out:
# (6000, 10) (2000, 10) (2000, 10)

# %%
print(target_scnd_train.shape, target_scnd_valid.shape, target_scnd_test.shape)
# Out:
# (6000,) (2000,) (2000,)

# %% [markdown]
# Данные поделены, перейдем к следующему этапу

# %% [markdown]
# ## Исследование задачи

# %% [markdown]
# Посмотрим на баланс классов в целевом признаке:

# %%
data['Exited'].value_counts()
# Out:
# 0    7963
# 1    2037
# Name: Exited, dtype: int64

# %% [markdown]
# Как мы видим класса "0" почти в 4 раза больше, чем класса "1". В выборке присутствует сильный дисбаланс.

# %% [markdown]
# Напишем функцию для отрисовки графика ROC-AUC кривой

# %%
def draw_roc_curve(y_values, x_values, estimator):
    probabilities_valid = estimator.predict_proba(x_values)
    probabilities_one_valid = probabilities_valid[:, 1]

    fpr, tpr, thresholds = roc_curve(y_values, probabilities_one_valid)
    roc_auc_value = roc_auc_score(y_values, probabilities_one_valid)
    plt.figure()
    
    plt.plot(fpr, tpr, color='darkorange',
             label=f'{str(estimator).split("(")[0]}, AUC-ROC = {round(roc_auc_value, 3)}')
    plt.plot([0, 1], [0, 1], color='navy', linestyle='--', label = 'random baseline')
    plt.xlim((0, 1))
    plt.ylim((0, 1))
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver operating characteristic example')
    plt.legend(loc="lower right")
    plt.show()

# %% [markdown]
# Также напишем функцию для отрисовки кривой валидации

# %%
def plot_validation_curve(estimator, X, y, 
                         param_name, param_range, cv, title,
                         scoring='f1'):
    train_scores, test_scores = validation_curve(
        estimator,
        X,
        y,
        param_name=param_name,
        param_range=param_range,
        scoring=scoring,
        n_jobs=1,
    )
    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)
    
    plt.title(title)
    plt.xlabel(param_name)
    plt.ylabel(str(scoring))
    plt.ylim(0.0, 1.1)
    lw = 2
    plt.plot(
        param_range,
        train_scores_mean,
        label="Training score",
        color='darkorange',
        lw=lw
    )
    plt.fill_between(
        param_range,
        train_scores_mean - train_scores_std,
        train_scores_mean + train_scores_std,
        alpha=0.4,
        color="darkorange",
        lw=lw,
    )
    plt.plot(
        param_range,
        test_scores_mean,
        label="Cross-validation score",
        color="navy",
        lw=lw
    )
    plt.fill_between(
        param_range,
        test_scores_mean - test_scores_std,
        test_scores_mean + test_scores_std,
        alpha=0.2,
        color="navy",
        lw=lw,
    )
    plt.legend(loc="best")
    plt.show()

# %% [markdown]
# ### Обучение модели на датасете с параметром Tenure

# %%
model_DT_first = DecisionTreeClassifier(max_depth=5, random_state=1)

# %%
model_DT_first.fit(features_first_train, target_first_train)
# Out:
# DecisionTreeClassifier(max_depth=5, random_state=1)

# %%
predictions_DT_first = model_DT_first.predict(features_first_valid)

# %% [markdown]
# Посмотрим на качество полученного предсказания используя метрику F1

# %%
print(f1_score(target_first_valid, predictions_DT_first))
# Out:
# 0.5598650927487353

# %% [markdown]
# Также оценим метрику ROC-AUC

# %%
draw_roc_curve(target_first_valid, features_first_valid, model_DT_first)

# %% [markdown]
# ### Обучение модели на датасете без параметра Tenure

# %%
model_DT_scnd = DecisionTreeClassifier(max_depth=5, random_state=1)

# %%
model_DT_scnd.fit(features_scnd_train, target_scnd_train)
# Out:
# DecisionTreeClassifier(max_depth=5, random_state=1)

# %%
predictions_DT_scnd = model_DT_scnd.predict(features_scnd_valid)

# %% [markdown]
# Теперь оценим качество модели без признака `Tenure`

# %%
print(f1_score(target_scnd_valid, predictions_DT_scnd))
# Out:
# 0.4761904761904762

# %% [markdown]
# Также оценим метрику ROC-AUC

# %%
draw_roc_curve(target_scnd_valid, features_scnd_valid, model_DT_scnd)

# %% [markdown]
# ### Подбор гиперпараметров

# %% [markdown]
# Поскольку качество моделей далеко отсовершенства, попробуем подобрать более оптимальные гиперпараметры

# %%
n_range = np.array(range(5, 55, 5))
tuned_parametrs = [{'max_depth' : n_range}]
tuned_parametrs
# Out:
# [{'max_depth': array([ 5, 10, 15, 20, 25, 30, 35, 40, 45, 50])}]

# %% [markdown]
# #### Модель для первого датасета

# %%
# %%time

tuned_DT_first = GridSearchCV(DecisionTreeClassifier(random_state=1), tuned_parametrs, cv=5, scoring='f1')
tuned_DT_first.fit(features_first, target_first)
# Out:
# Wall time: 1.56 s
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(random_state=1),
#              param_grid=[{'max_depth': array([ 5, 10, 15, 20, 25, 30, 35, 40, 45, 50])}],
#              scoring='f1')

# %%
tuned_DT_first.best_params_
# Out:
# {'max_depth': 10}

# %% [markdown]
# Отобразим график, показывающий, как изменялась мера F1 при различных значениях гиперпараметра **max_depth**

# %%
plt.plot(n_range, tuned_DT_first.cv_results_['mean_test_score'])

# %% [markdown]
# Также построим график валидации от изменения параметра **max_depth**

# %%
plot_validation_curve(tuned_DT_first.best_estimator_,
                      X=features_first_train,
                      y=target_first_train,
                      param_name='max_depth',
                      param_range=n_range,
                      cv=20,
                      title="Validation Curve with Decision Tree (but without Tenure param)",
                      scoring="f1")

# %% [markdown]
# #### Модель для второго датасета

# %%
# %%time

tuned_DT_scnd = GridSearchCV(DecisionTreeClassifier(random_state=1), tuned_parametrs, cv=5, scoring='f1')
tuned_DT_scnd.fit(features_scnd, target_scnd)
# Out:
# Wall time: 1.56 s
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(random_state=1),
#              param_grid=[{'max_depth': array([ 5, 10, 15, 20, 25, 30, 35, 40, 45, 50])}],
#              scoring='f1')

# %%
tuned_DT_scnd.best_params_
# Out:
# {'max_depth': 10}

# %% [markdown]
# И снова отобразим график, показывающий, как изменялась мера F1 при различных значениях гиперпараметра **max_depth**

# %%
plt.plot(n_range, tuned_DT_scnd.cv_results_['mean_test_score'])

# %% [markdown]
# Также построим график валидации от изменения параметра **max_depth**

# %%
plot_validation_curve(tuned_DT_scnd.best_estimator_,
                      X=features_scnd_train,
                      y=target_scnd_train,
                      param_name='max_depth',
                      param_range=n_range,
                      cv=20,
                      title="Validation Curve with Decision Tree (but with Tenure param)",
                      scoring="f1")

# %% [markdown]
# #### Обучение моделей после подбора гиперпараметров

# %%
tuned_DT_first.best_estimator_.fit(features_first_train, target_first_train)
# Out:
# DecisionTreeClassifier(max_depth=10, random_state=1)

# %%
predictions_tuned_first = tuned_DT_first.best_estimator_.predict(features_first_valid)

# %%
print(f1_score(target_first_valid, predictions_tuned_first))
# Out:
# 0.5339366515837104

# %%
draw_roc_curve(target_first_valid, features_first_valid, tuned_DT_first.best_estimator_)

# %%
tuned_DT_scnd.best_estimator_.fit(features_scnd_train, target_scnd_train)
# Out:
# DecisionTreeClassifier(max_depth=10, random_state=1)

# %%
predictions_tuned_scnd = tuned_DT_scnd.best_estimator_.predict(features_scnd_valid)

# %%
print(f1_score(target_scnd_valid, predictions_tuned_scnd))
# Out:
# 0.48914616497829233

# %%
draw_roc_curve(target_scnd_valid, features_scnd_valid, tuned_DT_scnd.best_estimator_)

# %% [markdown]
# #### Промежуточные выводы

# %% [markdown]
# После подбора гиперпараметров согласно метрикам F1 и ROC-AUC качество модели с параметром `Tenure` ухудшилось, а качество модели без параметра `Tenure` стало лучше по мере F1 и хуже по мере ROC-AUC. Вероятно при большей глубине дерева и таком же количестве данных модели начали переобучаться. Все еще виден сильный разрыв в оценках метрик между моделями в пользу модели, обученной на датасете с параметром `Tenure`

# %% [markdown]
# ## Борьба с дисбалансом

# %% [markdown]
# Для того, чтобы исправить проблему дисбаланса классов используем следующие методы:
#
# - попробуем изменить веса классов с помощью параметра **class_weight**
# - используем upsampling
# - используем downsampling

# %% [markdown]
# Для этого опишем функции **upsampling** и **downsampling**

# %%
def upsample(features, target, repeat):
    features_zeros = features[target == 0]
    features_ones = features[target == 1]
    target_zeros = target[target == 0]
    target_ones = target[target == 1]

    features_upsampled = pd.concat([features_zeros] + [features_ones] * repeat)
    target_upsampled = pd.concat([target_zeros] + [target_ones] * repeat)
    
    features_upsampled, target_upsampled = shuffle(
        features_upsampled, target_upsampled, random_state=1)
    
    return features_upsampled, target_upsampled

# %%
def downsample(features, target, fraction):
    features_zeros = features[target == 0]
    features_ones = features[target == 1]
    target_zeros = target[target == 0]
    target_ones = target[target == 1]

    features_downsampled = pd.concat(
        [features_zeros.sample(frac=fraction, random_state=1)] + [features_ones])
    target_downsampled = pd.concat(
        [target_zeros.sample(frac=fraction, random_state=1)] + [target_ones])
    
    features_downsampled, target_downsampled = shuffle(
        features_downsampled, target_downsampled, random_state=1)
    
    return features_downsampled, target_downsampled

# %% [markdown]
# Также подготовим датасеты для обучения моделей после использования этих техник

# %%
features_upsampled_first, target_upsampled_first = upsample(features_first_train, target_first_train, 4)

# %%
features_downsampled_first, target_downsampled_first = downsample(features_first_train, target_first_train, 0.25)

# %% [markdown]
# И для второго набора данных

# %%
features_upsampled_scnd, target_upsampled_scnd = upsample(features_scnd_train, target_scnd_train, 4)

# %%
features_downsampled_scnd, target_downsampled_scnd = downsample(features_scnd_train, target_scnd_train, 0.25)

# %% [markdown]
# Подготовим функцию для выполнения однотипных операций с моделями

# %%
def model_exploring(estimator, x_train, y_train, x_valid, y_valid):
    estimator.fit(x_train, y_train)
    predictions = estimator.predict(x_valid)
    print("F1-мера:", f1_score(y_valid, predictions))
    draw_roc_curve(y_valid, x_valid, estimator)

# %% [markdown]
# ### Дерево решений

# %% [markdown]
# #### На основе датасета с параметром Tenure

# %% [markdown]
# Настройка параметра **class_weight**

# %%
model_DT_first = DecisionTreeClassifier(max_depth=5, random_state=1, class_weight="balanced")

# %%
model_exploring(model_DT_first, features_first_train, target_first_train, features_first_valid, target_first_valid)
# Out:
# F1-мера: 0.569060773480663

# %% [markdown]
# Техника **Upsampling**

# %%
model_DT_first = DecisionTreeClassifier(max_depth=5, random_state=1)

# %%
model_exploring(model_DT_first, features_upsampled_first, target_upsampled_first, features_first_valid, target_first_valid)
# Out:
# F1-мера: 0.569060773480663

# %% [markdown]
# Техника **Downsampling**

# %%
model_exploring(model_DT_first, features_downsampled_first, target_downsampled_first, features_first_valid, target_first_valid)
# Out:
# F1-мера: 0.5492700729927007

# %% [markdown]
# #### На основе датасета без параметра Tenure

# %% [markdown]
# Настройка параметра **class_weight**

# %%
model_DT_scnd = DecisionTreeClassifier(max_depth=5, random_state=1, class_weight="balanced")

# %%
model_exploring(model_DT_scnd, features_scnd_train, target_scnd_train, features_scnd_valid, target_scnd_valid)
# Out:
# F1-мера: 0.5502262443438913

# %% [markdown]
# Техника **Upsampling**

# %%
model_DT_scnd = DecisionTreeClassifier(max_depth=5, random_state=1)

# %%
model_exploring(model_DT_scnd, features_upsampled_scnd, target_upsampled_scnd, features_scnd_valid, target_scnd_valid)
# Out:
# F1-мера: 0.5502262443438913

# %% [markdown]
# Техника **Downsampling**

# %%
model_exploring(model_DT_scnd, features_downsampled_scnd, target_downsampled_scnd, features_scnd_valid, target_scnd_valid)
# Out:
# F1-мера: 0.5495093666369313

# %% [markdown]
# ### Случайный лес

# %% [markdown]
# #### На основе датасета с параметром Tenure

# %% [markdown]
# Настройка параметра **class_weight**

# %%
model_RF_first = RandomForestClassifier(max_depth=10, random_state=1, class_weight="balanced")

# %%
model_exploring(model_RF_first, features_first_train, target_first_train, features_first_valid, target_first_valid)
# Out:
# F1-мера: 0.6251655629139072

# %% [markdown]
# Техника **Upsampling**

# %%
model_RF_first = RandomForestClassifier(max_depth=10, random_state=1)

# %%
model_exploring(model_RF_first, features_upsampled_first, target_upsampled_first, features_first_valid, target_first_valid)
# Out:
# F1-мера: 0.613744075829384

# %% [markdown]
# Техника **Downsampling**

# %%
model_exploring(model_RF_first, features_downsampled_first, target_downsampled_first, features_first_valid, target_first_valid)
# Out:
# F1-мера: 0.6132264529058117

# %% [markdown]
# #### На основе датасета без параметра Tenure

# %% [markdown]
# Настройка параметра **class_weight**

# %%
model_RF_scnd = RandomForestClassifier(max_depth=10, random_state=1, class_weight="balanced")

# %%
model_exploring(model_RF_scnd, features_scnd_train, target_scnd_train, features_scnd_valid, target_scnd_valid)
# Out:
# F1-мера: 0.6031746031746033

# %% [markdown]
# Техника **Upsampling**

# %%
model_RF_scnd = RandomForestClassifier(max_depth=10, random_state=1)

# %%
model_exploring(model_RF_scnd, features_upsampled_scnd, target_upsampled_scnd, features_scnd_valid, target_scnd_valid)
# Out:
# F1-мера: 0.6087936865839909

# %% [markdown]
# Техника **Downsampling**

# %%
model_exploring(model_RF_scnd, features_downsampled_scnd, target_downsampled_scnd, features_scnd_valid, target_scnd_valid)
# Out:
# F1-мера: 0.577397910731244

# %% [markdown]
# ### Логистическая регрессия

# %% [markdown]
# #### На основе датасета с параметром Tenure

# %% [markdown]
# Настройка параметра **class_weight**

# %%
model_LR_first = LogisticRegression(random_state=1, class_weight='balanced', max_iter=100)

# %%
model_exploring(model_LR_first, features_first_train, target_first_train, features_first_valid, target_first_valid)
# Out:
# F1-мера: 0.4305555555555555

# %% [markdown]
# Техника **Upsampling**

# %%
model_LR_first = LogisticRegression(random_state=1, max_iter=100)

# %%
model_exploring(model_LR_first, features_upsampled_first, target_upsampled_first, features_first_valid, target_first_valid)
# Out:
# F1-мера: 0.36183745583038873

# %% [markdown]
# Техника **Downsampling**

# %%
model_exploring(model_LR_first, features_downsampled_first, target_downsampled_first, features_first_valid, target_first_valid)
# Out:
# F1-мера: 0.4296675191815857

# %% [markdown]
# #### На основе датасета без параметра Tenure

# %% [markdown]
# Настройка параметра **class_weight**

# %%
model_LR_scnd = LogisticRegression(random_state=1, class_weight='balanced', max_iter=100)

# %%
model_exploring(model_LR_scnd, features_scnd_train, target_scnd_train, features_scnd_valid, target_scnd_valid)
# Out:
# F1-мера: 0.4880066170388751

# %% [markdown]
# Техника **Upsampling**

# %%
model_LR_scnd = LogisticRegression(random_state=1, max_iter=100)

# %%
model_exploring(model_LR_scnd, features_upsampled_scnd, target_upsampled_scnd, features_scnd_valid, target_scnd_valid)
# Out:
# F1-мера: 0.44637223974763407

# %% [markdown]
# Техника **Downsampling**

# %%
model_exploring(model_LR_scnd, features_downsampled_scnd, target_downsampled_scnd, features_scnd_valid, target_scnd_valid)
# Out:
# F1-мера: 0.4409695074276779

# %% [markdown]
# ### Промежуточные выводы

# %% [markdown]
# Из рассмотренных моделей лучше всего себя показала модель случайного леса, обученная на датасете с параметром `Tenure` и настройкой параметра **class_weight**. Она показала 0.625 оценку по метрике F1 и 0.865 по метрике ROC-AUC. Второй же моделью стала модель случайного леса с параметром `Tenure`, но с обученная на данных с применением техники **Upsample**. Она продемонстрировала оценку F1 равную 0.614 и ROC-AUC равную 0.865

# %% [markdown]
# Обе модели конкурентноспособны и сильно опережают своих конкурентов, поэтому именно для этих двух моделей проведем подбор гиперпараметров

# %% [markdown]
# ### Подбор гиперпараметров для лучших моделей

# %%
depth_range = np.array(range(5, 30, 5))
est_range = np.array(range(10, 51, 10))
tuned_parametrs = [{'max_depth' : depth_range, 
                   'n_estimators' : est_range}]
tuned_parametrs
# Out:
# [{'max_depth': array([ 5, 10, 15, 20, 25]),
#   'n_estimators': array([10, 20, 30, 40, 50])}]

# %% [markdown]
# #### Модель для первого датасета

# %%
# %%time

tuned_RF_first = GridSearchCV(RandomForestClassifier(random_state=1, class_weight='balanced'), tuned_parametrs, cv=5, scoring='f1')
tuned_RF_first.fit(features_first, target_first)
# Out:
# Wall time: 23 s
# GridSearchCV(cv=5,
#              estimator=RandomForestClassifier(class_weight='balanced',
#                                               random_state=1),
#              param_grid=[{'max_depth': array([ 5, 10, 15, 20, 25]),
#                           'n_estimators': array([10, 20, 30, 40, 50])}],
#              scoring='f1')

# %%
tuned_RF_first.best_params_
# Out:
# {'max_depth': 10, 'n_estimators': 50}

# %% [markdown]
# Отобразим график, показывающий, как изменялась мера F1 при различных значениях гиперпараметра **max_depth**

# %%
plot_validation_curve(tuned_RF_first.best_estimator_,
                      X=features_first_train,
                      y=target_first_train,
                      param_name='max_depth',
                      param_range=depth_range,
                      cv=20,
                      title="Validation Curve with Decision Tree (but without Tenure param)",
                      scoring="f1")

# %%
plot_validation_curve(tuned_RF_first.best_estimator_,
                      X=features_first_train,
                      y=target_first_train,
                      param_name='n_estimators',
                      param_range=est_range,
                      cv=20,
                      title="Validation Curve with Decision Tree (but without Tenure param)",
                      scoring="f1")

# %% [markdown]
# #### Модель для второго датасета

# %%
# %%time

tuned_RF_scnd = GridSearchCV(RandomForestClassifier(random_state=1), tuned_parametrs, cv=5, scoring='f1')
tuned_RF_scnd.fit(features_upsampled_first, target_upsampled_first)
# Out:
# Wall time: 20.6 s
# GridSearchCV(cv=5, estimator=RandomForestClassifier(random_state=1),
#              param_grid=[{'max_depth': array([ 5, 10, 15, 20, 25]),
#                           'n_estimators': array([10, 20, 30, 40, 50])}],
#              scoring='f1')

# %%
tuned_RF_scnd.best_params_
# Out:
# {'max_depth': 25, 'n_estimators': 40}

# %% [markdown]
# И снова отобразим график, показывающий, как изменялась мера F1 при различных значениях гиперпараметра **max_depth**

# %%
plot_validation_curve(tuned_RF_scnd.best_estimator_,
                      X=features_scnd_train,
                      y=target_scnd_train,
                      param_name='max_depth',
                      param_range=depth_range,
                      cv=20,
                      title="Validation Curve with Decision Tree (but with Tenure param)",
                      scoring="f1")

# %% [markdown]
# Также отобразим график, показывающий, как изменялась мера F1 при различных значениях гиперпараметра **n_estimators**

# %%
plot_validation_curve(tuned_RF_scnd.best_estimator_,
                      X=features_first_train,
                      y=target_first_train,
                      param_name='n_estimators',
                      param_range=est_range,
                      cv=20,
                      title="Validation Curve with Decision Tree (but without Tenure param)",
                      scoring="f1")

# %% [markdown]
# #### Анализ полученных гиперпараметров

# %% [markdown]
# Судя по графикам валидации, увеличение параметра **n_estimators** не даст почти никакого прироста к оценке метрикой F1, а обучение такого количества деревьев не затратит значительно больше времени. Также можно заметить, что при значении глубины дерева больше, чем 10 первая модель начинает переобучаться, соответственно это и будет нашим оптимальным значением гиперпараметра **max_depth**, для второй модели это число будет равно 15

# %% [markdown]
# #### Последнее сравнение моделей

# %% [markdown]
# Обучим наши модели на полученных оптимальных значениях гиперпараметров.

# %% [markdown]
# ##### На основе датасета с параметром Tenure и настройкой class_weight

# %%
model_RF_first = RandomForestClassifier(random_state=1, class_weight='balanced', max_depth=10, n_estimators=25)

# %%
model_exploring(model_RF_first, features_first_train, target_first_train, features_first_valid, target_first_valid)
# Out:
# F1-мера: 0.6206896551724138

# %% [markdown]
# ##### На основе датасета c параметром Tenure и техникой upsample

# %%
model_RF_scnd = RandomForestClassifier(random_state=1, max_depth=15, n_estimators=40)

# %%
model_exploring(model_RF_scnd, features_upsampled_first, target_upsampled_first, features_first_valid, target_first_valid)
# Out:
# F1-мера: 0.6191117092866757

# %% [markdown]
# ##### Выбор лучшей модели

# %% [markdown]
# Согласно полученным условиям, модель должна иметь оценку мо метрике F1 не меньше, чем 0,59. Из полученных нами моделей этому условию удовлетворяют обе, они имеют почти равные оценки по используемым метрикам, однако чуть лучше эти оценки у модели, обученной с настройкой параметра **class_weight**, поэтому ее и выберем как лучшую модель

# %% [markdown]
# ## Тестирование модели

# %% [markdown]
# Проведем тестирование полученной лучшей модели, посчитав значение метрики F1 и ROC-AUC на тестовой выборке

# %% [markdown]
# Дообучим лучшую модель на общих данных обучающей и валидационной выборки

# %%
merged_df_features = pd.concat([features_first_train, features_first_valid], axis=0)
merged_df_target = pd.concat([target_first_train, target_first_valid], axis=0)

# %%
print(merged_df_features.shape, merged_df_target.shape)
# Out:
# (7272, 11) (7272,)

# %%
model_exploring(model_RF_first, merged_df_features, merged_df_target, features_first_test, target_first_test)
# Out:
# F1-мера: 0.5964912280701754

# %% [markdown]
# Полученная метрика F1 равна 0,594; В свою очередь метрика ROC-AUC равна 0,848. Найденная лучшая модель удовлетворяет полученным условиям.

# %% [markdown]
# ## Выводы

# %% [markdown]
# В ходе проведенного исследования были изучены полученные данные, изучено поведение моделей при дисбалансе классов и при его устранении, выбрана оптимальная модель. В результате можно сделать следующие выводы:
#
# * Для моделей решающего дерева использование различных техник борьбы с дисбалансом классов способно принести +-1% в оценку F1
# * Почти для всех моделей случайного леса наименее эффективно себя показала техника **Downsampling**, вероятно это связано с тем, что модели чувствительны к количеству данных для обучения, которое сильно уменьшилось в результате работы этой техники
# * Почти для всех моделей настройка параметра **class_weight** показала себя, как наиболее эффективный способ борьбы с дисбалансом классов.
# * Лучшей моделью стала модель случайного леса с глубиной дерева 10 и количеством деревьев 25, и с использованием параметра **class_weight**
# * Оценка лучшей модели на тестовой выборке F1-мера: 0,59; ROC-AUC: 0,849.
# * Модели основанные на датасете с параметром `Tenure` показывают себя лучше их аналогов без этого параметра
